# %%
## Data Storytelling using titanic dataset Exploratory data analysis

# %%
# What is EDA (Exploratory Data Analysis)
# Steps to follow for EDA:
# Understanding the data (Understanding columns,understanding values,try to find meaning of dataset)
# There are two types of columns: Categorical columns and Numerical columns
# Identify the types of columns present in dataset from above types
# Check for number of missing values in columns in dataset
# Cleaning the data
# Missing values imputation--use median for numerical column and mode for categorical column
# Feature selections: this helps identity which variables are most important for your problem (feature engineering & selection)
# Assumtions checking: this allows you to check assumpttions that are required for certain machine learning models
# Generally dataset have two types of columns categorical column and numerical columnn. can there can be more than this type of columns?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid')

# %% [markdown]
# ##### Data loading and initial inspection of data

# %%
# !git clone "https://github.com/Py-Ninad/Datasets"
# Out:
# fatal: destination path 'Datasets' already exists and is not an empty directory.

# %%
df = pd.read_csv("Datasets/Titanic_Dataset/Titanic-Dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
print('Dataset information')
df.info()
# Out:
# Dataset information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Insights:
# This dataset have both null values as well as non-null values.
# we need to check null values quantity if any of column have more null values then need to focus on that columns
# so cleaning and sorting of dataset will be simple

# %%
print('Describe Dataset')
df.describe()
# Out:
# Describe Dataset
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F2             3
# D              3
#               ..
# E17            1
# A24            1
# C50            1
# B42            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %% [markdown]
# ### Data Cleanings steps ahead

# %% [markdown]
# ##### Missing values imputation
# For Numerical data: use median &
# For Categorial data: use mode (most frequent value) &
# For too many missing values: eg Cabin column where most of the data is missing,imputing might not be effective here.
# so we can either drop the entire column or engineer a new feature (new column) from that column eg 'has_cabin'

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
median = df['Age'].median()
print(median)
# Out:
# 28.0

# %%
# Filling Age column null values
median = df['Age'].median()
df['Age'] = df['Age'].fillna(median)

# %%
df.isnull().sum()  # Now here we can notice that Age column dont have anymore null values ie all values got filled.Now only cabin column remained and embarked
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
mode_embarked = df['Embarked'].mode()[0]

# %%
df['Embarked'] = df['Embarked'].fillna(mode_embarked)

# %%
df.isnull().sum()  # now Embarked coulmn have 0 null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
# now need to handle Cabin column

df['Has_Cabin'] = df['Cabin'].notna().astype(int)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Has_Cabin'].value_counts()
# Out:
# Has_Cabin
# 0    687
# 1    204
# Name: count, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Has_Cabin      0
# dtype: int64

# %%
# For Categorical column --> we can use pie chart,bar charts,frequency tables so we can see proportion of each category
# For numerical column ---> we can histogram,box plot,kernal distribution plot so we can identify central tendancy, spread and outliers

# %%
# df.isna().head()
df.notna().head()
# Out:
#    PassengerId  Survived  Pclass  Name   Sex   Age  SibSp  Parch  Ticket  \
# 0         True      True    True  True  True  True   True   True    True
# 1         True      True    True  True  True  True   True   True    True
# 2         True      True    True  True  True  True   True   True    True
# 3         True      True    True  True  True  True   True   True    True
# 4         True      True    True  True  True  True   True   True    True
#
#    Fare  Embarked  Has_Cabin
# 0  True      True       True
# 1  True      True       True
# 2  True      True       True
# 3  True      True       True
# 4  True      True       True

# %%
df.isnull().head()
# df.notnull().head()
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
# 3        False     False   False  False  False  False  False  False   False
# 4        False     False   False  False  False  False  False  False   False
#
#     Fare  Embarked  Has_Cabin
# 0  False     False      False
# 1  False     False      False
# 2  False     False      False
# 3  False     False      False
# 4  False     False      False

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Has_Cabin      0
# dtype: int64

# %% [markdown]
# ##### Univeriate Analysis

# %%
# plotting a chart using matplotlib
fig,axes = plt.subplots(2,3,figsize = (15,10))
fig.suptitle('Univariate analysis of Categorial features',fontsize=14)


sns.countplot(ax=axes[0,0],x='Survived',data=df).set_title("Survival Distribution")
sns.countplot(ax=axes[0,1],x='Pclass',data=df).set_title('Passenger Class Distribution')
sns.countplot(ax=axes[0,2],x='Sex',data=df).set_title('Gender Distribution')
sns.countplot(ax=axes[1,0],x='Embarked',data=df).set_title('Port of embarkation')
sns.countplot(ax=axes[1,1],x='SibSp',data=df).set_title('Sibilng/Spouse aboard')
sns.countplot(ax=axes[1,2],x='Parch',data=df).set_title('Parents/childrens aboard')
# Out:
# Text(0.5, 1.0, 'Parents/childrens aboard')

# %%
# Analzing numerical features now
print('Numerical columns')

fig,axes = plt.subplots(1,2,figsize=(11,5))
fig.suptitle('Univariate analysis of Numerical Features',fontsize = 14)

sns.histplot(ax=axes[0],data=df,x='Age',kde=True,bins=30).set_title('Age Distribution')

sns.histplot(ax=axes[1],data=df,x='Fare',kde=True,bins=40).set_title('Fare Distribution')
# Out:
# Numerical columns
# Text(0.5, 1.0, 'Fare Distribution')

# %% [markdown]
# ##### Bivariat analysis

# %%
fig, axes = plt.subplots(2,2,figsize=(16,14))
fig.suptitle('Bivariate Analysis with Survival',fontsize=14)

# Pclass vs Survived
sns.barplot(ax=axes[0,0],x='Pclass',y='Survived',data=df).set_title('Survival Rate by Passenger Class')

# Sex vs Survived
sns.barplot(ax=axes[0,1],x='Sex',y='Survived',data=df).set_title('Survival Rate by Sex')

# Embarked vs Survived
sns.barplot(ax=axes[1,0],x='Embarked',y='Survived',data=df).set_title('Survival Rate by Boarding place')

# Has_Cabin vs Survived
sns.barplot(ax=axes[1,1],x='Has_Cabin',y='Survived',data=df).set_title('Survival Rate by Passengers who had cabin')

plt.tight_layout(rect=[0,0,1,0.95])
plt.show()

# %%
# TODO: find more about confidence intervals ie black lines in above bar plots

# %% [markdown]
# ##### Deeper Dive into outlier 'Fare'

# %%
# Previously the describe function and a histogram showed that Fare has extreme outliers.Lets visualize this clearly with box plot

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare   Has_Cabin
# count  891.000000  891.000000  891.000000
# mean     0.381594   32.204208    0.228956
# std      0.806057   49.693429    0.420397
# min      0.000000    0.000000    0.000000
# 25%      0.000000    7.910400    0.000000
# 50%      0.000000   14.454200    0.000000
# 75%      0.000000   31.000000    0.000000
# ...

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='Fare',data=df)
plt.title('Box Plot of ticket fare')
plt.ylabel('Fare')
plt.show()

# %%
# Insights:
# the circles are the outliers also dark black line at zero is the min and dark black line near to 100 is max and those circles are the outliers
# for machine learning models handling these outliers are very important (use log transformation)

# %% [markdown]
# #### Feature Engineering

# %%
# Feature engineering is the process of extracting features ie (Characteristics, properties,attributes of dataset) using a domain knowledge from raw data.
# A good feature should be relevant to the problem and easy for model to understand

# Techniques:
# 1.Combing new features: Creating a new feature by combing others (eg Sibsp + Parch = FamilySize)
# 2.Extrating from Text:Pulling out specific information from text feature (eg extracting title from Name columns mr.,mrs.,master,miss)
# 3.Binning: Converting a contious numerical feature into categorical one (eg binning 'Age' into groups like 'Child','Senior','Adult')

# %%
# Creating familysize feature
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1  # Why +1 b'coz traveller is 1 person & that persons family

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Creating isAlone Feature
df['isAlone'] = 0
df.loc[df['FamilySize']==1,'isAlone'] = 1  # understand loc function for this
df[['FamilySize','isAlone']].head()
# Out:
#    FamilySize  isAlone
# 0           2        0
# 1           2        0
# 2           1        1
# 3           2        0
# 4           1        1

# %%
# Now analyzing new feature column with survival
fig,axes = plt.subplots(1,2,figsize=(10,5))

#Survival rate by Family Size
sns.barplot(ax=axes[0],x='FamilySize',y='Survived',data=df).set_title('Survival rate by family size')

#Survival rate by isAlone
sns.barplot(ax=axes[1],x='isAlone',y='Survived',data=df).set_title('Survival rate by isAlone')

plt.show()

# %%
# now extract Title (Mr. or Mrs. or Miss. or Master) from name column by using regex
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Title'] = df['Name'].str.extract(r' ([A-Za-z]+)\.',expand=False)
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Embarked  Has_Cabin  FamilySize  isAlone  \
# 0      0         A/5 21171   7.2500        S          0           2        0
# 1      0          PC 17599  71.2833        C          1           2        0
# 2      0  STON/O2. 3101282   7.9250        S          0           1        1
#
#   Title
# 0    Mr
# 1   Mrs
# 2  Miss

# %%
 df['Title'].value_counts()
# Out:
# Title
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Mlle          2
# Major         2
# Ms            1
# Mme           1
# Don           1
# Lady          1
# Sir           1
# Capt          1
# Countess      1
# Jonkheer      1
# Name: count, dtype: int64

# %%
df['Title'] = df['Title'].replace(['Lady','Countess','Capt','Col','Don','Dr','Major','Rev','Sir','Jonkheer','Dona'],'Rare')

df['Title'] = df['Title'].replace('Mlle','Miss')
df['Title'] = df['Title'].replace('Ms','Miss')
df['Title'] = df['Title'].replace('Mme','Miss')

plt.figure(figsize=(11,5))
sns.barplot(x='Title',y='Survived',data=df)
plt.title('Survivale rate by Title')
plt.ylabel('Survival probability')
plt.show()

# %% [markdown]
# #### Multivariate Analysis

# %%
sns.catplot(x='Pclass',y='Survived',data=df,hue='Sex',kind='bar',height=6)
plt.title("Survivate rate by Pclass and Sex")
plt.show()

# %%
# Insights: First class people survived the most mostly females then females of the second class

# %%
plt.figure(figsize=(14,7))
sns.violinplot(x='Sex',y='Age',data=df,hue='Survived',split=True,palette = {0:'yellow',1:'pink'})
plt.title('Age distribution by Sex and Survival')
plt.show()

# %% [markdown]
# #### Corelation analysis

# %%
plt.figure(figsize=(14,5))
numeric_cols = df.select_dtypes(include=np.number)
correlation_matrix = numeric_cols.corr()

sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Correlation matrix of numerical features')
plt.show()

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# C:\Users\N!nad\AppData\Local\Programs\Python\Python313\python.exe
# 3.13.3 (tags/v3.13.3:6280bb5, Apr  8 2025, 14:47:33) [MSC v.1943 64 bit (AMD64)]

# %%
import sys
# !{sys.executable} -m pip install -U ydata-profiling[notebook]
# !pip install jupyter-contrib-nbextensions

# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: console contrib dejavu events execute kernel kernelspec
# lab labextension labhub migrate nbconvert nbextensions_configurator notebook
# run server troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.

# %%
from ydata_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 from ydata_profiling import ProfileReport
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\ydata_profiling\__init__.py:10
#       6 import warnings  # isort:skip # noqa
#       8 import importlib.util  # isort:skip # noqa
# ---> 10 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      11 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      12 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\ydata_profiling\compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
# ...
